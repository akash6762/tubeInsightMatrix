# %%
from googleapiclient.discovery import build
import json

# %%
youtube = build("youtube", "v3", developerKey = "AIzaSyAgwzSCHzY0_nLZPzOzQ3jSoWatEI6Njsk")

# %%
res = youtube.playlistItems().list(playlistId = "UUY6KjrDBN_tIRFT_QNqQbRQ",
                                      part = "snippet",
                                      maxResults = 50).execute()
print(res)
# Out:
# {'kind': 'youtube#playlistItemListResponse', 'etag': 'oeR5V02dFXl1dTs9lptGAhJ6VDQ', 'nextPageToken': 'EAAafVBUOkNESWlFRGhETlVaQlJUWkNNVFkwT0RFelF6Z29BVWk3OGJEQ3J0aUVBMUFCV2pnaVEyaG9WbFpXYXpKVE1uQjVVa1ZLVDFnelVrcFZhMXBWV0RGR1QyTldSbWxWYkVWVFJFRnBkVzl3UzNaQ2FFUTBia2t6T0VGUkln', 'items': [{'kind': 'youtube#playlistItem', 'etag': 'KZEDO3ixwZSzfdDNuuAK13L_Tq8', 'id': 'VVVZNktqckRCTl90SVJGVF9RTnFRYlJRLlFaR3lPYnl1QktR', 'snippet': {'publishedAt': '2024-03-03T08:16:00Z', 'channelId': 'UCY6KjrDBN_tIRFT_QNqQbRQ', 'title': 'REVIEW!! 🔥 Apple Vision Pro 🤯 |  Madan Gowri | Tamil | MG', 'description': 'In this video, Madan Gowri shares his user experience and reviews about the newly launched Apple Vision Pro, which he bought recently. He tells the positives and negatives about the Apple Vision Pro after using it for a few days and He also explores a few exciting features of Apple Vision Pro in this review video. This includes, watching LEO movie on top of the Himalayas, Using different natural envi
# ...

# %%
def get_video_ids(playlist_id):
    
    videos = []
    next_page_token = None

    while True:
        res = youtube.playlistItems().list(playlistId = "UUY6KjrDBN_tIRFT_QNqQbRQ",
                                      part = "snippet",
                                      maxResults = 50).execute()
    videos += res["items"]
    next_page_token = res.get("nextPageToken")

    if next_page_token is None:
        break

    return videos

print(get_video_ids("UUY6KjrDBN_tIRFT_QNqQbRQ"))
# Out:
#   Cell In[11], line 14
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
request = youtube.playlistItems().list(
            playlistId = "UUY6KjrDBN_tIRFT_QNqQbRQ", 
            part = "snippet",
            maxResults = 1,
            pageToken = None
        )
response = request.execute()
print(json.dumps(response, indent= 4))
# Out:
# {
#     "kind": "youtube#playlistItemListResponse",
#     "etag": "MOh7ZDVDZURvjHgZhDJQMuJFuAE",
#     "nextPageToken": "EAAafVBUOkNBRWlFREk0T1VZMFFUUTJSRVl3UVRNd1JESW9BVWk3OGJEQ3J0aUVBMUFCV2pnaVEyaG9WbFpXYXpKVE1uQjVVa1ZLVDFnelVrcFZhMXBWV0RGR1QyTldSbWxWYkVWVFJFRnBkVzl3UzNaQ2FFUTBia2t6T0VGUkln",
#     "items": [
#         {
#             "kind": "youtube#playlistItem",
#             "etag": "KZEDO3ixwZSzfdDNuuAK13L_Tq8",
#             "id": "VVVZNktqckRCTl90SVJGVF9RTnFRYlJRLlFaR3lPYnl1QktR",
#             "snippet": {
#                 "publishedAt": "2024-03-03T08:16:00Z",
#                 "channelId": "UCY6KjrDBN_tIRFT_QNqQbRQ",
#                 "title": "REVIEW!! \ud83d\udd25 Apple Vision Pro \ud83e\udd2f |  Madan Gowri | Tamil | MG",
# ...
